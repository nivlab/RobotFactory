# %%
import numpy as np
from pandas import DataFrame
from scipy.io import loadmat

# %%
df
# Out:
#      Cue                  X        RT  ...  Trial  Condition  Exposure
# 0      2    Go-to-win-right       NaN  ...      1          1         1
# 1      6        NoGo-to-win       NaN  ...      2          1         1
# 2      7      NoGo-to-avoid       NaN  ...      3          1         1
# 3      1     Go-to-win-left       NaN  ...      4          1         1
# 4      5        NoGo-to-win       NaN  ...      5          1         1
# 5      1     Go-to-win-left  0.492381  ...      6          1         2
# 6      7      NoGo-to-avoid       NaN  ...      7          1         2
# 7      7      NoGo-to-avoid       NaN  ...      8          1         3
# 8      1     Go-to-win-left  0.634473  ...      9          1         3
# 9      4  Go-to-avoid-right  0.770389  ...     10          1         1
# 10     4  Go-to-avoid-right  0.478156  ...     11          1         2
# 11     3   Go-to-avoid-left       NaN  ...     12          1         1
# ...
